# %%
from quadtree_with_vis import *

visbuild = Visualizer()
visfind = Visualizer()
points = [(1, 1), (2.5, 2.5), (3, 3), (4, 4), (5, 5), (2, 6), (8, 9), (6, 7)]
region = ((1, 2), (5, 6))
qtree = QuadTree(Rectangle(Point((0, 0)), Point((10, 10))),
                 points, visbuild, visfind)
rect = Rectangle(Point((1, 2)), Point((5, 6)))
result2 = qtree.find(rect, qtree.node)
qtree.visbuild.show_gif()
# Out:
# (2, 6)

# %%
qtree.visfind.show_gif()
